# %% [markdown]
# <a href="https://colab.research.google.com/github/anithash89/Campaigns_Data_Analysis_Cleansing/blob/main/Campaigns_Data_Cleansing_Explore_Dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # USE CASE : Calculate the Total salesamount for each store id and campaigns for respective week
# # Step 1 : Import required libraries
# # Step2 : Create Campaign Sample data 1
# # Step 3: Create Campaign Sample data 2
# # Step 4 : Merge or combine the data 1 and data 2
# # Step 5 : Remove Duplicates
# # Step 6 : Check for Null values
# # Step 7 : Remove Null value rows
# # Step 8 : Calculate sum of amount for each store and for each week
# # Step 9 : Plot the graph

# %% [markdown]
# # Importing all required libraries

# %%
import pandas as pd #importing pandas module to do data analysis
import numpy as np # To do mathematical calculations and Null values identification
import matplotlib.pyplot as plt #FOR GRAPH REPRESENTATION
import csv

# %% [markdown]
# # Create Sample Raw data 1
# #Create Raw data (Sample test data) which contains StoreID and Campaign information for each week and corresponding Sales amount

# %%
    

#raw_data1 = {'StoreId': ['1', '2', '3', '4', '8'],
 #               'StoreSize': ['medium', np.NAN, 'small', 'medium', 'large'],
  #              'Campaigns': [1, 2, 3, 1, 2],
   #             'Week': [1, 2, 3, 4, 1],
    #            'SalesAmount': [25, 25, 49, 62, 70]}

#df1 = pd.DataFrame(raw_data1, columns = ['StoreId', 'Storesize','AgeofOutlets' ,'Campaigns',
                                          # 'Week', 'SalesAmount'])
df1=pd.read_csv('https://raw.githubusercontent.com/anithash89/Campaigns_Data_Analysis_Cleansing/main/rawdata1.csv')
print(df1)
# Out:
#      StoreID Storesize  AgeofOutlets  Campaigns  Week  SalesAmount
# 0          1    Medium           4.0        3.0     1         33.73
# 1          1    Medium           4.0        3.0     1         35.67
# 2          1    Medium           4.0        3.0     3         29.03
# 3          1    Medium           4.0        3.0     4         39.25
# 4          2    Medium           5.0        2.0     1         27.81
# ..       ...       ...           ...        ...   ...           ...
# 399      704    Medium          27.0        1.0     2         46.06
# 400      704    Medium          27.0        1.0     3         55.46
# 401      704    Medium          27.0        1.0     4         51.41
# 402      705    Medium          22.0        3.0     1         49.67
# 403      705    Medium          22.0        3.0     2         49.98
#
# [404 rows x 6 columns]

# %% [markdown]
# ## Creating Sample data 2 similar to Sample data 1

# %%
#raw_data2 = {'StoreId': ['1', '2', '30', '94', '50'],
 #               'StoreSize': ['medium', 'small', 'small', 'medium', 'small'],
  #              'Campaigns': [1, 3,np.NaN, 1, 1],
   #             'Week': [1, 2, 3, 4, 1],
    #            'SalesAmount': [25, 45, 67, 65, 72]}

#df2 = pd.DataFrame(raw_data2, columns = ['StoreId', 'StoreSize', 'Campaigns',
 #                                          'Week', 'SalesAmount'])
df2=pd.read_csv('https://raw.githubusercontent.com/anithash89/Campaigns_Data_Analysis_Cleansing/main/rawdata2.csv')
print(df2)
df2
# Out:
#      StoreID Storesize  AgeofOutlets  Campaigns  Week  SalesAmount
# 0        705    Medium            22          3     4         47.35
# 1        706    Medium            17          3     1         50.26
# 2        706    Medium            17          3     2         52.05
# 3        706    Medium            17          3     3         51.14
# 4        706    Medium            17          3     4         46.30
# ..       ...       ...           ...        ...   ...           ...
# 144      919     Large             2          1     4         64.34
# 145      920     Large            14          2     1         50.20
# 146      920     Large            14          2     2         45.75
# 147      920     Large            14          2     3         44.29
# 148      920     Large            14          2     4         49.41
#
# [149 rows x 6 columns]
#      StoreID Storesize  AgeofOutlets  Campaigns  Week  SalesAmount
# 0        705    Medium            22          3     4         47.35
# 1        706    Medium            17          3     1         50.26
# 2        706    Medium            17          3     2         52.05
# 3        706    Medium            17          3     3         51.14
# 4        706    Medium            17          3     4         46.30
# ..       ...       ...           ...        ...   ...           ...
# 144      919     Large             2          1     4         64.34
# 145      920     Large            14          2     1         50.20
# 146      920     Large            14          2     2         45.75
# 147      920     Large            14          2     3         44.29
# 148      920     Large            14          2     4         49.41
#
# [149 rows x 6 columns]

# %% [markdown]
# # **Merge or combine  2 data sets**

# %%
Merge_df = [df1,df2]
Merge_result =pd.concat(Merge_df)
Merge_result
# Out:
#      StoreID Storesize  AgeofOutlets  Campaigns  Week  SalesAmount
# 0          1    Medium           4.0        3.0     1         33.73
# 1          1    Medium           4.0        3.0     1         35.67
# 2          1    Medium           4.0        3.0     3         29.03
# 3          1    Medium           4.0        3.0     4         39.25
# 4          2    Medium           5.0        2.0     1         27.81
# ..       ...       ...           ...        ...   ...           ...
# 144      919     Large           2.0        1.0     4         64.34
# 145      920     Large          14.0        2.0     1         50.20
# 146      920     Large          14.0        2.0     2         45.75
# 147      920     Large          14.0        2.0     3         44.29
# 148      920     Large          14.0        2.0     4         49.41
#
# [553 rows x 6 columns]

# %% [markdown]
# # **# Remove the duplicate columns based on each StoreId,Week, and SalesAmount**

# %%
Dup_result=Merge_result.drop_duplicates(subset=['StoreID','Week','SalesAmount '])
Dup_result
# Out:
#      StoreID Storesize  AgeofOutlets  Campaigns  Week  SalesAmount
# 0          1    Medium           4.0        3.0     1         33.73
# 1          1    Medium           4.0        3.0     1         35.67
# 2          1    Medium           4.0        3.0     3         29.03
# 3          1    Medium           4.0        3.0     4         39.25
# 4          2    Medium           5.0        2.0     1         27.81
# ..       ...       ...           ...        ...   ...           ...
# 144      919     Large           2.0        1.0     4         64.34
# 145      920     Large          14.0        2.0     1         50.20
# 146      920     Large          14.0        2.0     2         45.75
# 147      920     Large          14.0        2.0     3         44.29
# 148      920     Large          14.0        2.0     4         49.41
#
# [547 rows x 6 columns]

# %% [markdown]
# # **# Check for Missing values or Null values **

# %%
missing=Dup_result.isnull()
missing
# Out:
#      StoreID  Storesize  AgeofOutlets  Campaigns   Week  SalesAmount
# 0      False      False         False      False  False         False
# 1      False      False         False      False  False         False
# 2      False      False         False      False  False         False
# 3      False      False         False      False  False         False
# 4      False      False         False      False  False         False
# ..       ...        ...           ...        ...    ...           ...
# 144    False      False         False      False  False         False
# 145    False      False         False      False  False         False
# 146    False      False         False      False  False         False
# 147    False      False         False      False  False         False
# 148    False      False         False      False  False         False
#
# [547 rows x 6 columns]

# %% [markdown]
# # **## Remove the Missing values and clean the data from the result of duplicates**
#
# # **# The RESULT is CLEAN data **

# %%
cleanse=Dup_result.dropna()
cleanse
# Out:
#      StoreID Storesize  AgeofOutlets  Campaigns  Week  SalesAmount
# 0          1    Medium           4.0        3.0     1         33.73
# 1          1    Medium           4.0        3.0     1         35.67
# 2          1    Medium           4.0        3.0     3         29.03
# 3          1    Medium           4.0        3.0     4         39.25
# 4          2    Medium           5.0        2.0     1         27.81
# ..       ...       ...           ...        ...   ...           ...
# 144      919     Large           2.0        1.0     4         64.34
# 145      920     Large          14.0        2.0     1         50.20
# 146      920     Large          14.0        2.0     2         45.75
# 147      920     Large          14.0        2.0     3         44.29
# 148      920     Large          14.0        2.0     4         49.41
#
# [542 rows x 6 columns]

# %% [markdown]
# # **Calculate Sum of salesamount for each store and for each week**

# %%
SumOfSales = cleanse.groupby(['StoreID','Week','Campaigns']).sum('SalesAmount ')
SumOfSales
# Out:
#                         AgeofOutlets  SalesAmount
# StoreID Week Campaigns
# 1       1    3.0                 8.0         69.40
#         3    3.0                 4.0         29.03
#         4    3.0                 4.0         39.25
# 2       1    2.0                 5.0         27.81
#         2    2.0                 5.0         34.67
# ...                              ...           ...
# 919     4    1.0                 2.0         64.34
# 920     1    2.0                14.0         50.20
#         2    2.0                14.0         45.75
#         3    2.0                14.0         44.29
#         4    2.0                14.0         49.41
#
# [541 rows x 2 columns]

# %% [markdown]
# ## **Final Result: The Store Id 4 in the week of 4 has got increased Sales amount**

# %%
SumOfSales.plot()
